# %% [markdown]
# ### This data is formatted the next way
# - Every Excel has N different pages for fruit/vegetable group like "Manzana"
# - We don't know all the pages there are as they change (probably because of seasons, offer/demand)
# - All pages are separated into 2 groups, the first one for Wholesale prices, the second Wholesale volumes
# - We have (hopefully) the same number of datapoints in the first and second group.
# - Datapoints are formatted in the following columns: 'Variety', 'Market Name', 'Monday', 'Tuesday', 'Wednesday', 'Thrustday', 'Friday', 'Commerce Unit'.
# - Commerce Units are directly related between price and volume but need formatting to merge.

# %% [markdown]
# ### Which fruits/vegetables have the highest/lowest sales volume and revenue?
#     Identify the top-selling and least-selling products in terms of volume and revenue to understand the most and least popular items.
#
# ### What are the sales trends for specific fruits/vegetables over time?
#     Analyze weekly sales data to identify seasonal trends, demand patterns, and potential growth opportunities.
#
# ### What is the average price and volume sold per unit for each fruit/vegetable?
#     Calculate the average price and volume to understand the typical market conditions for different products.
#
# ### Which markets show the highest/lowest sales for specific fruits/vegetables?
#     Determine the geographical regions with the highest and lowest sales to optimize distribution and marketing efforts.
#
# ### What is the overall revenue and volume for all fruits/vegetables combined?
#     Provide an overview of total revenue and volume to showcase the overall performance of the business.
#
# ### Are there any price or volume fluctuations over time?
#     Analyze price and volume variations to identify factors affecting sales and potential pricing strategies.
#
# ### Which fruits/vegetables have the highest profit margins?
#     Calculate profit margins for each product to identify opportunities for maximizing profitability.
#
# ### What are the best-selling fruits/vegetables in each market?
#     Determine the top products in each market to guide inventory management and marketing efforts.
#
# ### Can we identify any correlations between price and volume for specific products?
#     Conduct a correlation analysis to explore the relationship between price and volume for individual items.
#
# ### What is the overall market share of each fruit/vegetable?
#     Calculate the market share of each product to understand its position compared to competitors.
#
# ### How do pricing strategies impact sales volume and revenue?
#     Analyze the effect of pricing changes on sales performance to optimize pricing strategies.
#
# ### Which fruits/vegetables have the highest customer satisfaction or repeat purchase rates?
#     Use customer feedback data to identify products with high satisfaction levels and loyal customers.
#
# ### Can we forecast future sales for specific products based on historical data?
#     Utilize time series analysis and forecasting techniques to predict future sales for individual items.
#
# ### What are the most profitable markets for each fruit/vegetable?
#     Analyze the profit margins across different markets to identify lucrative opportunities.
#
# ### Are there any product combinations that lead to increased sales?
#     Analyze cross-selling patterns to identify potential product bundling opportunities.

# %%
import pandas as pd
import numpy as np
import dateparser
import re
from datetime import datetime, timedelta
import os
import math

# %%
def findBetween(datestr, start, end):
    # Simple find string function
    pattern = re.escape(start) + r'(.*?)' + re.escape(end)
    matches = re.findall(pattern, datestr)
    return matches[0]
def extractDates(datestr):
    try:
        # Second date is full
        second_date = dateparser.parse(datestr.split('al ')[1])
        
        # First date day or day+month
        first_day = findBetween(datestr, 'Semana del ', ' al')
        first_date = None
        
        # Dates comes in two formats
        if not first_day.isnumeric():
            # Example: Semana del 27 de junio al 1 de julio 2022
            first_day, first_month = first_day.split(' de ')
            first_month = dateparser.parse(f"{first_day} de {first_month} de {second_date.year}").month
            first_date = second_date.replace(day=int(first_day), month=first_month)
            
            if (second_date - first_date) < timedelta(days=0):
                first_date = first_date.replace(year=first_date.year - 1)
        else:
            # Example: Semana del 09 al 13 de marzo de 2015
            first_day = int(first_day)
            first_date = second_date.replace(day=first_day)
        return [first_date, second_date]
    except Exception as e:
        print('Extract Dates: ', datestr, e)
def formatDateStr(datestr):
    # Dates in filenames can come in two formats
    try:
        new_date = dateparser.parse(datestr, date_formats=['%Y%m%d'])
        if new_date == None:
            new_date = dateparser.parse(datestr, date_formats=['%d%m%Y'])
            return new_date
        else:
            return new_date
    except Exception as e:
        print(e, datestr)
        return None

# %%
# First 2 values are not products
df = pd.read_excel('./data/Boletin_Semanal_Precios_Mayoristas_20230714.xlsx', sheet_name=None)
sheet_names = list(df.keys())
sheet_names
# Out:
# ['Portada Boletin semanal',
#  'Presentación',
#  'Cebolla',
#  'Lechuga',
#  'Limón',
#  'Manzana',
#  'Naranja',
#  'Palta',
#  'Papa',
#  'Pera',
#  'Tomate',
#  'Uva',
#  'Zanahoria']

# %%
excel_files = os.listdir('./data/')
excel_files[0]
# Out:
# 'Boletin_Semanal_Precios_Mayoristas_20220128.xlsx'

# %%
path_data = './data/'
excel_files = os.listdir(path_data)
excel_files
# Out:
# ['Boletin_Semanal_Precios_Mayoristas_20220128.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20230224.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20200306.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20230210.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20190412.xlsx',
#  'Boletin-semanal-precios-mayoristas-06042018.xlsx',
#  'Boletin-semanal-precios-mayoristas_14092018.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20201231.xlsx',
#  'Boletin-semanal-precios-mayoristas-15062018.xlsx',
#  'Boletin-semanal-precios-mayoristas-27072018.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20210806.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20210205.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20221007.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20210709.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20200828.xlsx',
#  'Boletin_semanal_precios_mayoristas_20190705.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20201224.xlsx',
#  'Boletin-precios-mayoristas-2015-03-07-a-13.xls',
#  'Boletin-semanal-precios-mayoristas_07092018.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20210604.xlsx',
#  'Boletin_semanal_precios_mayoristas_20190524.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20230414.xlsx',
#  'boletinSemana19_23Dic.xls',
#  'Boletin_semanal_precios_mayoristas_20191108.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20230623.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20230406.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20200925.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20211231.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20220708.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20221104.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20190308.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20210514.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20230505.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20201030.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20200228.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20230630.xlsx',
#  'Boletin-semanal-precios-mayoristas_31102018.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20220805.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20200515.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20220701.xlsx',
#  'Boletin-semanal-precios-mayoristas_24082018.xlsx',
#  'Boletin_semanal_precios_mayoristas_20190607.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20210212.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20200717.xlsx',
#  'Boletin-semanal-precios-mayoristas-24-28_agosto.xls',
#  'Boletin_Semanal_Precios_Mayoristas_20201120.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20220812.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20200522.xlsx',
#  'Boletin_semanal_precios_mayoristas_20190510.xlsx',
#  'Boletin-semanal-precios-mayoristas-11052018.xlsx',
#  'Boletin-precios-mayoristas-2015-07-13-a-17.xls',
#  'Boletin_Semanal_Precios_Mayoristas_20220225.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20210108.xlsx',
#  'Boletin_semanal_precios_mayoristas_20190917.xlsx',
#  'Boletin_semanal_precios_mayoristas_20200207.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20230317.xlsx',
#  'Boletin-semanal-precios-mayoristas-02032018.xlsx',
#  'Boletin-semanal-precios-mayoristas-26062017.xls',
#  'Boletin_semanal_precios_mayoristas_20200124.xlsx',
#  'Boletin_semanal_precios_mayoristas_20191018.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20230602.xlsx',
#  'Boletin_semanal_precios_mayoristas_20181109.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20190222.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20220121.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20210219.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20210305.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20221223.xlsx',
#  'BSemanalPreciosMayoristas_20211126.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20200508.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20210903.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20230512.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20210702.xlsx',
#  'Boletin_semanal_precios_mayoristas_20190906.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20210312.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20
xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20211022.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20190301.xlsx',
#  'Boletin_semanal_precios_mayoristas_20191030.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20200619.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20210528.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20220506.xlsx',
#  'Boletin_Semanal_Precios_Mayoristas_20230331.xlsx']

# %%
path_data = './data/'
test_file = 'Boletin-precios-mayoristas-2015-03-07-a-13.xls'

# %%
path_data = './data/'
excel_files = os.listdir(path_data)
selected_excels = []
target_date = datetime(2018,9,21)

for excel_file in excel_files:
    pattern = r'(\d+)\.xlsx'
    match = re.search(pattern, excel_file)
    if match:
        parsed_date = formatDateStr(match.group(1))
        if parsed_date > target_date:
            selected_excels.append({'date':parsed_date, 'file': excel_file})
    else:
        continue
    continue
    
    """df = pd.read_excel(path_data + excel_file, sheet_name=None)
    sheet_names = list(df.keys())[2:] # Take out the first 2
    selected_sheet = sheet_names[-1]
    df_sheet = pd.read_excel(path_data + excel_file, sheet_name=selected_sheet)
    try:
        print(excel_file)
        dates = extractDates(str(df_sheet.iloc[1][0]))
        print(selected_sheet, dates[0])
        if dates[0] > target_date:
            selected_excels.append(excel_file)
    except Exception as e:
        print(e, sheet_names, excel_file)
    if (dates[1]+timedelta(days=1)-dates[0]) < timedelta(days=5):
        print(path_data+excel_file, sheet)"""
sorted_data = sorted(selected_excels, key=lambda x: x['date'])

# %%
sorted_data
# Out:
# [{'date': datetime.datetime(2018, 9, 28, 0, 0),
#   'file': 'Boletin-semanal-precios-mayoristas_28092018.xlsx'},
#  {'date': datetime.datetime(2018, 10, 5, 0, 0),
#   'file': 'Boletin-semanal-precios-mayoristas_05102018.xlsx'},
#  {'date': datetime.datetime(2018, 10, 12, 0, 0),
#   'file': 'Boletin-semanal-precios-mayoristas_12102018.xlsx'},
#  {'date': datetime.datetime(2018, 10, 19, 0, 0),
#   'file': 'Boletin-semanal-precios-mayoristas_19102018.xlsx'},
#  {'date': datetime.datetime(2018, 10, 26, 0, 0),
#   'file': 'Boletin-semanal-precios-mayoristas_26102018.xlsx'},
#  {'date': datetime.datetime(2018, 10, 31, 0, 0),
#   'file': 'Boletin-semanal-precios-mayoristas_31102018.xlsx'},
#  {'date': datetime.datetime(2018, 11, 9, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20181109.xlsx'},
#  {'date': datetime.datetime(2018, 11, 16, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas-20181116.xlsx'},
#  {'date': datetime.datetime(2018, 11, 23, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20181123.xlsx'},
#  {'date': datetime.datetime(2018, 11, 30, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20181130.xlsx'},
#  {'date': datetime.datetime(2018, 12, 7, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20181207.xlsx'},
#  {'date': datetime.datetime(2018, 12, 14, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20181214.xlsx'},
#  {'date': datetime.datetime(2018, 12, 28, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20181228.xlsx'},
#  {'date': datetime.datetime(2019, 1, 4, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20190104.xlsx'},
#  {'date': datetime.datetime(2019, 1, 11, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20190111.xlsx'},
#  {'date': datetime.datetime(2019, 1, 18, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20190118.xlsx'},
#  {'date': datetime.datetime(2019, 1, 25, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20190125.xlsx'},
#  {'date': datetime.datetime(2019, 2, 1, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20190201.xlsx'},
#  {'date': datetime.datetime(2019, 2, 8, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20190208.xlsx'},
#  {'date': datetime.datetime(2019, 2, 15, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20190215.xlsx'},
#  {'date': datetime.datetime(2019, 2, 22, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20190222.xlsx'},
#  {'date': datetime.datetime(2019, 3, 1, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20190301.xlsx'},
#  {'date': datetime.datetime(2019, 3, 8, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20190308.xlsx'},
#  {'date': datetime.datetime(2019, 3, 15, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20190315.xlsx'},
#  {'date': datetime.datetime(2019, 3, 22, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20190322.xlsx'},
#  {'date': datetime.datetime(2019, 3, 29, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20190329.xlsx'},
#  {'date': datetime.datetime(2019, 4, 5, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20190405.xlsx'},
#  {'date': datetime.datetime(2019, 4, 12, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20190412.xlsx'},
#  {'date': datetime.datetime(2019, 4, 18, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20190418.xlsx'},
#  {'date': datetime.datetime(2019, 4, 26, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20190426.xlsx'},
#  {'date': datetime.datetime(2019, 5, 3, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20190503.xlsx'},
#  {'date': datetime.datetime(2019, 5, 10, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20190510.xlsx'},
#  {'date': datetime.datetime(2019, 5, 17, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20190517.xlsx'},
#  {'date': datetime.datetime(2019, 5, 24, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20190524.xlsx'},
#  {'date': datetime.datetime(2019, 5, 31, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20190531.xlsx'},
#  {'date': datetime.datetime(2019, 6, 7, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20190607.xlsx'},
#  {'date': datetime.datetime(2019, 6, 14, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20190614.xlsx'},
#  {'date': datetime.datetime(2019, 6, 21, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20190621.xlsx'},
#  {'date': datetime.datetime(2019, 6, 28, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20190628.xlsx'},
#  {'date': datetime.datetime(2019, 7, 5, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20190705.xlsx'},
#  {'date': datetime.datetime(2019, 7, 12, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20190712.xlsx'},
#  {'date': datetime.datetime(2019, 7, 19, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20190719.xlsx'},
#  {'date': datetime.datetime(2019, 7, 26, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20190726.xlsx'},
#  {'date': datetime.datetime(2019, 8, 2, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20190802.xlsx'},
#  {'date': datetime.datetime(2019, 8, 9, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20190809.xlsx'},
#  {'date': datetime.datetime(2019, 8, 16, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20190816.xlsx'},
#  {'date': datetime.datetime(2019, 8, 23, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20190823.xlsx'},
#  {'date': datetime.datetime(2019, 8, 30, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20190830.xlsx'},
#  {'date': datetime.datetime(2019, 9, 6, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20190906.xlsx'},
#  {'date': datetime.datetime(2019, 9, 13, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20190913.xlsx'},
#  {'date': datetime.datetime(2019, 9, 17, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20190917.xlsx'},
#  {'date': datetime.datetime(2019, 9, 27, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20190927.xlsx'},
#  {'date': datetime.datetime(2019, 10, 4, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20191004.xlsx'},
#  {'date': datetime.datetime(2019, 10, 11, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20191011.xlsx'},
#  {'date': datetime.datetime(2019, 10, 18, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20191018.xlsx'},
#  {'date': datetime.datetime(2019, 10, 25, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20191025.xlsx'},
#  {'date': datetime.datetime(2019, 10, 30, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20191030.xlsx'},
#  {'date': datetime.datetime(2019, 11, 8, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20191108.xlsx'},
#  {'date': datetime.datetime(2019, 11, 15, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20191115.xlsx'},
#  {'date': datetime.datetime(2019, 11, 22, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20191122.xlsx'},
#  {'date': datetime.datetime(2019, 11, 29, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20191129.xlsx'},
#  {'date': datetime.datetime(2019, 12, 6, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20191206.xlsx'},
#  {'date': datetime.datetime(2019, 12, 13, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20191213.xlsx'},
#  {'date': datetime.datetime(2019, 12, 20, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20191220.xlsx'},
#  {'date': datetime.datetime(2019, 12, 27, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20191227.xlsx'},
#  {'date': datetime.datetime(2020, 1, 3, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20200103.xlsx'},
#  {'date': datetime.datetime(2020, 1, 10, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20200110.xlsx'},
#  {'date': datetime.datetime(2020, 1, 17, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20200117.xlsx'},
#  {'date': datetime.datetime(2020, 1, 24, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20200124.xlsx'},
#  {'date': datetime.datetime(2020, 1, 31, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20200131.xlsx'},
#  {'date': datetime.datetime(2020, 2, 7, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20200207.xlsx'},
#  {'date': datetime.datetime(2020, 2, 14, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20200214.xlsx'},
#  {'date': datetime.datetime(2020, 2, 21, 0, 0),
#   'file': 'Boletin_semanal_precios_mayoristas_20200221.xlsx'},
#  {'date': datetime.datetime(2020, 2, 28, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20200228.xlsx'},
#  {'date': datetime.datetime(2020, 3, 6, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20200306.xlsx'},
#  {'date': datetime.datetime(2020, 3, 13, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20200313.xlsx'},
#  {'date': datetime.datetime(2020, 3, 20, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20200320.xlsx'},
#  {'date': datetime.datetime(2020, 3, 27, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20200327.xlsx'},
#  {'date': datetime.datetime(2020, 4, 3, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20200403.xlsx'},
#  {'date': datetime.datetime(2020, 4, 9, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20200409.xlsx'},
#  {'date': datetime.datetime(2020, 4, 17, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20200417.xlsx'},
#  {'date': datetime.datetime(2020, 4, 24, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20200424.xlsx'},
#  {'date': datetime.datetime(2020, 5, 1, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20200501.xlsx'},
#  {'date': datetime.datetime(2020, 5, 8, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20200508.xlsx'},
#  {'date': datetime.datetime(2020, 5, 15, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20200515.xlsx'},
#  {'date': datetime.datetime(2020, 5, 22, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20200522.xlsx'},
#  {'date': datetime.datetime(2020, 5, 29, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20200529.xlsx'},
#  {'date': datetime.datetime(2020, 6, 5, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20200605.xlsx'},
#  {'date': datetime.datetime(2020, 6, 19, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20200619.xlsx'},
#  {'date': datetime.datetime(2020, 6, 26, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20200626.xlsx'},
#  {'date': datetime.datetime(2020, 7, 3, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20200703.xlsx'},
#  {'date': datetime.datetime(2020, 7, 10, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20200710.xlsx'},
#  {'date': datetime.datetime(2020, 7, 17, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20200717.xlsx'},
#  {'date': datetime.datetime(2020, 7, 24, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20200724.xlsx'},
#  {'date': datetime.datetime(2020, 7, 31, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20200731.xlsx'},
#  {'date': datetime.datetime(2020, 8, 7, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20200807.xlsx'},
#  {'date': datetime.datetime(2020, 8, 14, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20200814.xlsx'},
#  {'date': datetime.datetime(2020, 8, 21, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20200821.xlsx'},
#  {'date': datetime.datetime(2020, 8, 28, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20200828.xlsx'},
#  {'date': datetime.datetime(2020, 9, 4, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20200904.xlsx'},
#  {'date': datetime.datetime(2020, 9, 11, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20200911.xlsx'},
#  {'date': datetime.datetime(2020, 9, 17, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20200917.xlsx'},
#  {'date': datetime.datetime(2020, 9, 25, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20200925.xlsx'},
#  {'date': datetime.datetime(2020, 10, 2, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20201002.xlsx'},
#  {'date': datetime.datetime(2020, 10, 9, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20201009.xlsx'},
#  {'date': datetime.datetime(2020, 10, 16, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20201016.xlsx'},
#  {'date': datetime.datetime(2020, 10, 23, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20201023.xlsx'},
#  {'date': datetime.datetime(2020, 10, 30, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20201030.xlsx'},
#  {'date': datetime.datetime(2020, 11, 6, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20201106.xlsx'},
#  {'date': datetime.datetime(2020, 11, 13, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20201113.xlsx'},
#  {'date': datetime.datetime(2020, 11, 20, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20201120.xlsx'},
#  {'date': datetime.datetime(2020, 11, 27, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20201127.xlsx'},
#  {'date': datetime.datetime(2020, 12, 4, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20201204.xlsx'},
#  {'date': datetime.datetime(2020, 12, 11, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20201211.xlsx'},
#  {'date': datetime.datetime(2020, 12, 18, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20201218.xlsx'},
#  {'date': datetime.datetime(2020, 12, 24, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20201224.xlsx'},
#  {'date': datetime.datetime(2020, 12, 31, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20201231.xlsx'},
#  {'date': datetime.datetime(2021, 1, 8, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210108.xlsx'},
#  {'date': datetime.datetime(2021, 1, 15, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210115.xlsx'},
#  {'date': datetime.datetime(2021, 1, 22, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210122.xlsx'},
#  {'date': datetime.datetime(2021, 1, 29, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210129.xlsx'},
#  {'date': datetime.datetime(2021, 2, 5, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210205.xlsx'},
#  {'date': datetime.datetime(2021, 2, 12, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210212.xlsx'},
#  {'date': datetime.datetime(2021, 2, 19, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210219.xlsx'},
#  {'date': datetime.datetime(2021, 2, 26, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210226.xlsx'},
#  {'date': datetime.datetime(2021, 3, 5, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210305.xlsx'},
#  {'date': datetime.datetime(2021, 3, 12, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210312.xlsx'},
#  {'date': datetime.datetime(2021, 3, 19, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210319.xlsx'},
#  {'date': datetime.datetime(2021, 3, 26, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210326.xlsx'},
#  {'date': datetime.datetime(2021, 4, 1, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210401.xlsx'},
#  {'date': datetime.datetime(2021, 4, 9, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210409.xlsx'},
#  {'date': datetime.datetime(2021, 4, 16, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210416.xlsx'},
#  {'date': datetime.datetime(2021, 4, 23, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210423.xlsx'},
#  {'date': datetime.datetime(2021, 4, 30, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210430.xlsx'},
#  {'date': datetime.datetime(2021, 5, 7, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210507.xlsx'},
#  {'date': datetime.datetime(2021, 5, 14, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210514.xlsx'},
#  {'date': datetime.datetime(2021, 5, 20, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210520.xlsx'},
#  {'date': datetime.datetime(2021, 5, 28, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210528.xlsx'},
#  {'date': datetime.datetime(2021, 6, 4, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210604.xlsx'},
#  {'date': datetime.datetime(2021, 6, 11, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210611.xlsx'},
#  {'date': datetime.datetime(2021, 6, 18, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210618.xlsx'},
#  {'date': datetime.datetime(2021, 6, 25, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210625.xlsx'},
#  {'date': datetime.datetime(2021, 7, 2, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210702.xlsx'},
#  {'date': datetime.datetime(2021, 7, 9, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210709.xlsx'},
#  {'date': datetime.datetime(2021, 7, 15, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210715.xlsx'},
#  {'date': datetime.datetime(2021, 7, 23, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210723.xlsx'},
#  {'date': datetime.datetime(2021, 7, 30, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210730.xlsx'},
#  {'date': datetime.datetime(2021, 8, 6, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210806.xlsx'},
#  {'date': datetime.datetime(2021, 8, 13, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210813.xlsx'},
#  {'date': datetime.datetime(2021, 8, 20, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210820.xlsx'},
#  {'date': datetime.datetime(2021, 8, 27, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210827.xlsx'},
#  {'date': datetime.datetime(2021, 9, 3, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210903.xlsx'},
#  {'date': datetime.datetime(2021, 9, 10, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210910.xlsx'},
#  {'date': datetime.datetime(2021, 9, 16, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210916.xlsx'},
#  {'date': datetime.datetime(2021, 9, 24, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20210924.xlsx'},
#  {'date': datetime.datetime(2021, 10, 1, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20211001.xlsx'},
#  {'date': datetime.datetime(2021, 10, 8, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20211008.xlsx'},
#  {'date': datetime.datetime(2021, 10, 15, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20211015.xlsx'},
#  {'date': datetime.datetime(2021, 10, 22, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20211022.xlsx'},
#  {'date': datetime.datetime(2021, 10, 29, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20211029.xlsx'},
#  {'date': datetime.datetime(2021, 11, 5, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20211105.xlsx'},
#  {'date': datetime.datetime(2021, 11, 12, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20211112.xlsx'},
#  {'date': datetime.datetime(2021, 11, 19, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20211119.xlsx'},
#  {'date': datetime.datetime(2021, 11, 26, 0, 0),
#   'file': 'BSemanalPreciosMayoristas_20211126.xlsx'},
#  {'date': datetime.datetime(2021, 12, 3, 0, 0),
#   'file': 'BSemanalPreciosMayoristas20211203.xlsx'},
#  {'date': datetime.datetime(2021, 12, 10, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20211210.xlsx'},
#  {'date': datetime.datetime(2021, 12, 17, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20211217.xlsx'},
#  {'date': datetime.datetime(2021, 12, 24, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20211224.xlsx'},
#  {'date': datetime.datetime(2021, 12, 31, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20211231.xlsx'},
#  {'date': datetime.datetime(2022, 1, 7, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220107.xlsx'},
#  {'date': datetime.datetime(2022, 1, 14, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220114.xlsx'},
#  {'date': datetime.datetime(2022, 1, 21, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220121.xlsx'},
#  {'date': datetime.datetime(2022, 1, 28, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220128.xlsx'},
#  {'date': datetime.datetime(2022, 2, 4, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220204.xlsx'},
#  {'date': datetime.datetime(2022, 2, 11, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220211.xlsx'},
#  {'date': datetime.datetime(2022, 2, 18, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220218.xlsx'},
#  {'date': datetime.datetime(2022, 2, 25, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220225.xlsx'},
#  {'date': datetime.datetime(2022, 3, 4, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220304.xlsx'},
#  {'date': datetime.datetime(2022, 3, 11, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220311.xlsx'},
#  {'date': datetime.datetime(2022, 3, 18, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220318.xlsx'},
#  {'date': datetime.datetime(2022, 3, 25, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220325.xlsx'},
#  {'date': datetime.datetime(2022, 4, 1, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220401.xlsx'},
#  {'date': datetime.datetime(2022, 4, 8, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220408.xlsx'},
#  {'date': datetime.datetime(2022, 4, 15, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220415.xlsx'},
#  {'date': datetime.datetime(2022, 4, 22, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220422.xlsx'},
#  {'date': datetime.datetime(2022, 4, 29, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220429.xlsx'},
#  {'date': datetime.datetime(2022, 5, 6, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220506.xlsx'},
#  {'date': datetime.datetime(2022, 5, 13, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220513.xlsx'},
#  {'date': datetime.datetime(2022, 5, 20, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220520.xlsx'},
#  {'date': datetime.datetime(2022, 5, 27, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220527.xlsx'},
#  {'date': datetime.datetime(2022, 6, 3, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220603.xlsx'},
#  {'date': datetime.datetime(2022, 6, 10, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220610.xlsx'},
#  {'date': datetime.datetime(2022, 6, 17, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220617.xlsx'},
#  {'date': datetime.datetime(2022, 6, 24, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220624.xlsx'},
#  {'date': datetime.datetime(2022, 7, 1, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220701.xlsx'},
#  {'date': datetime.datetime(2022, 7, 8, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220708.xlsx'},
#  {'date': datetime.datetime(2022, 7, 15, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220715.xlsx'},
#  {'date': datetime.datetime(2022, 7, 22, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220722.xlsx'},
#  {'date': datetime.datetime(2022, 7, 29, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220729.xlsx'},
#  {'date': datetime.datetime(2022, 8, 5, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220805.xlsx'},
#  {'date': datetime.datetime(2022, 8, 12, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220812.xlsx'},
#  {'date': datetime.datetime(2022, 8, 19, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220819.xlsx'},
#  {'date': datetime.datetime(2022, 8, 26, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220826.xlsx'},
#  {'date': datetime.datetime(2022, 9, 2, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220902.xlsx'},
#  {'date': datetime.datetime(2022, 9, 9, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220909.xlsx'},
#  {'date': datetime.datetime(2022, 9, 15, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220915.xlsx'},
#  {'date': datetime.datetime(2022, 9, 23, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220923.xlsx'},
#  {'date': datetime.datetime(2022, 9, 30, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20220930.xlsx'},
#  {'date': datetime.datetime(2022, 10, 7, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20221007.xlsx'},
#  {'date': datetime.datetime(2022, 10, 14, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20221014.xlsx'},
#  {'date': datetime.datetime(2022, 10, 21, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20221021.xlsx'},
#  {'date': datetime.datetime(2022, 10, 28, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20221028.xlsx'},
#  {'date': datetime.datetime(2022, 11, 4, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20221104.xlsx'},
#  {'date': datetime.datetime(2022, 11, 11, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20221111.xlsx'},
#  {'date': datetime.datetime(2022, 11, 18, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20221118.xlsx'},
#  {'date': datetime.datetime(2022, 11, 25, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20221125.xlsx'},
#  {'date': datetime.datetime(2022, 12, 2, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20221202.xlsx'},
#  {'date': datetime.datetime(2022, 12, 9, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20221209.xlsx'},
#  {'date': datetime.datetime(2022, 12, 16, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20221216.xlsx'},
#  {'date': datetime.datetime(2022, 12, 23, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20221223.xlsx'},
#  {'date': datetime.datetime(2022, 12, 30, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20221230.xlsx'},
#  {'date': datetime.datetime(2023, 1, 6, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20230106.xlsx'},
#  {'date': datetime.datetime(2023, 1, 13, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20230113.xlsx'},
#  {'date': datetime.datetime(2023, 1, 20, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20230120.xlsx'},
#  {'date': datetime.datetime(2023, 1, 27, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20230127.xlsx'},
#  {'date': datetime.datetime(2023, 2, 3, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20230203.xlsx'},
#  {'date': datetime.datetime(2023, 2, 10, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20230210.xlsx'},
#  {'date': datetime.datetime(2023, 2, 17, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20230217.xlsx'},
#  {'date': datetime.datetime(2023, 2, 24, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20230224.xlsx'},
#  {'date': datetime.datetime(2023, 3, 3, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20230303.xlsx'},
#  {'date': datetime.datetime(2023, 3, 10, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20230310.xlsx'},
#  {'date': datetime.datetime(2023, 3, 17, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20230317.xlsx'},
#  {'date': datetime.datetime(2023, 3, 24, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20230324.xlsx'},
#  {'date': datetime.datetime(2023, 3, 31, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20230331.xlsx'},
#  {'date': datetime.datetime(2023, 4, 6, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20230406.xlsx'},
#  {'date': datetime.datetime(2023, 4, 14, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20230414.xlsx'},
#  {'date': datetime.datetime(2023, 4, 21, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20230421.xlsx'},
#  {'date': datetime.datetime(2023, 4, 28, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20230428.xlsx'},
#  {'date': datetime.datetime(2023, 5, 5, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20230505.xlsx'},
#  {'date': datetime.datetime(2023, 5, 12, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20230512.xlsx'},
#  {'date': datetime.datetime(2023, 5, 19, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20230519.xlsx'},
#  {'date': datetime.datetime(2023, 5, 26, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20230526.xlsx'},
#  {'date': datetime.datetime(2023, 6, 2, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20230602.xlsx'},
#  {'date': datetime.datetime(2023, 6, 9, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20230609.xlsx'},
#  {'date': datetime.datetime(2023, 6, 16, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20230616.xlsx'},
#  {'date': datetime.datetime(2023, 6, 23, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20230623.xlsx'},
#  {'date': datetime.datetime(2023, 6, 30, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20230630.xlsx'},
#  {'date': datetime.datetime(2023, 7, 7, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20230707.xlsx'},
#  {'date': datetime.datetime(2023, 7, 14, 0, 0),
#   'file': 'Boletin_Semanal_Precios_Mayoristas_20230714.xlsx'}]

# %%
"""path_data = './data/'
excel_files = os.listdir(path_data)
selected_excels = []
target_date = datetime(2018,9,21)

for excel_file in excel_files:
    df = pd.read_excel(path_data + excel_file, sheet_name=None)
    sheet_names = list(df.keys())[2:] # Take out the first 2
    selected_sheet = sheet_names[-1]
    df_sheet = pd.read_excel(path_data + excel_file, sheet_name=selected_sheet)
    try:
        print(excel_file)
        dates = extractDates(str(df_sheet.iloc[1][0]))
        print(selected_sheet, dates[0])
        if dates[0] > target_date:
            selected_excels.append(excel_file)
    except Exception as e:
        print(e, sheet_names, excel_file)
    if (dates[1]+timedelta(days=1)-dates[0]) < timedelta(days=5):
        print(path_data+excel_file, sheet)
selected_excels""";

# %%
# Solve different sheet format
"""path_data = './data/'
for data in sorted_data:
    df_sheets = pd.read_excel(path_data + data['file'], sheet_name=None)
    sheet_names = list(df_sheets.keys())[2:] #Remove 'Portada...' and 'Presentacion'
    for sheet in sheet_names:
        df = pd.read_excel(path_data + data['file'], sheet_name=sheet)
        print(extractDates(str(df.iloc[1][0])), sheet)"""
# Out:
# [datetime.datetime(2018, 9, 24, 0, 0), datetime.datetime(2018, 9, 28, 0, 0)] Cebolla
# [datetime.datetime(2018, 9, 24, 0, 0), datetime.datetime(2018, 9, 28, 0, 0)] Lechuga
# [datetime.datetime(2018, 9, 24, 0, 0), datetime.datetime(2018, 9, 28, 0, 0)] Limón
# [datetime.datetime(2018, 9, 24, 0, 0), datetime.datetime(2018, 9, 28, 0, 0)] Manzana
# [datetime.datetime(2018, 9, 24, 0, 0), datetime.datetime(2018, 9, 28, 0, 0)] Naranja
# [datetime.datetime(2018, 9, 24, 0, 0), datetime.datetime(2018, 9, 28, 0, 0)] Palta
# [datetime.datetime(2018, 9, 24, 0, 0), datetime.datetime(2018, 9, 28, 0, 0)] Papa
# [datetime.datetime(2018, 9, 24, 0, 0), datetime.datetime(2018, 9, 28, 0, 0)] Pera
# [datetime.datetime(2018, 9, 24, 0, 0), datetime.datetime(2018, 9, 28, 0, 0)] Tomate
# [datetime.datetime(2018, 9, 24, 0, 0), datetime.datetime(2018, 9, 28, 0, 0)] Zanahoria
# [datetime.datetime(2018, 10, 15, 0, 0), datetime.datetime(2018, 10, 19, 0, 0)] Zanahoria
# [datetime.datetime(2018, 10, 22, 0, 0), datetime.datetime(2018, 10, 26, 0, 0)] Cebolla
# [datetime.datetime(2018, 10, 22, 0, 0), datetime.datetime(2018, 10, 26, 0, 0)] Lechuga
# [datetime.datetime(2018, 10, 22, 0, 0), datetime.datetime(2018, 10, 26, 0, 0)] Limón
# [datetime.datetime(2018, 10, 22, 0, 0), datetime.datetime(2018, 10, 26, 0, 0)] Manzana
# [datetime.datetime(2018, 10, 22, 0, 0), datetime.datetime(2018, 10, 26, 0, 0)] Naranja
# [datetime.datetime(2018, 10, 22, 0, 0), datetime.datetime(2018, 10, 26, 0, 0)] Palta
# [datetime.datetime(2018, 10, 22, 0, 0), datetime.datetime(2018, 10, 26, 0, 0)] Papa
# [datetime.datetime(2018, 10, 22, 0, 0), datetime.datetime(2018, 10, 26, 0, 0)] Pera
# [datetime.datetime(2018, 10, 22, 0, 0), datetime.datetime(2018, 10, 26, 0, 0)] Tomate
# [datetime.datetime(2018, 10, 22, 0, 0), datetime.datetime(2018, 10, 26, 0, 0)] Zanahoria
# [datetime.datetime(2018, 10, 29, 0, 0), datetime.datetime(2018, 11, 2, 0, 0)] Cebolla
# [datetime.datetime(2018, 10, 29, 0, 0), datetime.datetime(2018, 11, 2, 0, 0)] Lechuga
# [datetime.datetime(2018, 10, 29, 0, 0), datetime.datetime(2018, 11, 2, 0, 0)] Limón
# [datetime.datetime(2018, 10, 29, 0, 0), datetime.datetime(2018, 11, 2, 0, 0)] Manzana
# [datetime.datetime(2018, 10, 29, 0, 0), datetime.datetime(2018, 11, 2, 0, 0)] Naranja
# [datetime.datetime(2018, 10, 29, 0, 0), datetime.datetime(2018, 11, 2, 0, 0)] Palta
# [datetime.datetime(2018, 10, 29, 0, 0), datetime.datetime(2018, 11, 2, 0, 0)] Papa
# [datetime.datetime(2018, 10, 29, 0, 0), datetime.datetime(2018, 11, 2, 0, 0)] Pera
# [datetime.datetime(2018, 10, 29, 0, 0), datetime.datetime(2018, 11, 2, 0, 0)] Tomate
# [datetime.datetime(2018, 10, 29, 0, 0), datetime.datetime(2018, 11, 2, 0, 0)] Zanahoria
# [datetime.datetime(2018, 11, 5, 0, 0), datetime.datetime(2018, 11, 9, 0, 0)] Cebolla
# [datetime.datetime(2018, 11, 5, 0, 0), datetime.datetime(2018, 11, 9, 0, 0)] Lechuga
# [datetime.datetime(2018, 11, 5, 0, 0), datetime.datetime(2018, 11, 9, 0, 0)] Limón
# [datetime.datetime(2018, 11, 5, 0, 0), datetime.datetime(2018, 11, 9, 0, 0)] Manzana
# [datetime.datetime(2018, 11, 5, 0, 0), datetime.datetime(2018, 11, 9, 0, 0)] Naranja
# [datetime.datetime(2018, 11, 5, 0, 0), datetime.datetime(2018, 11, 9, 0, 0)] Palta
# [datetime.datetime(2018, 11, 5, 0, 0), datetime.datetime(2018, 11, 9, 0, 0)] Papa
# [datetime.datetime(2019, 3, 18, 0, 0), datetime.datetime(2019, 3, 22, 0, 0)] Pera
# [datetime.datetime(2019, 3, 18, 0, 0), datetime.datetime(2019, 3, 22, 0, 0)] Tomate
# [datetime.datetime(2019, 3, 18, 0, 0), datetime.datetime(2019, 3, 22, 0, 0)] Uva
# [datetime.datetime(2019, 3, 18, 0, 0), datetime.datetime(2019, 3, 22, 0, 0)] Zanahoria
# [datetime.datetime(2019, 3, 25, 0, 0), datetime.datetime(2019, 3, 29, 0, 0)] Cebolla
# [datetime.datetime(2019, 3, 25, 0, 0), datetime.datetime(2019, 3, 29, 0, 0)] Lechuga
# [datetime.datetime(2019, 3, 25, 0, 0), datetime.datetime(2019, 3, 29, 0, 0)] Limón
# [datetime.datetime(2019, 3, 25, 0, 0), datetime.datetime(2019, 3, 29, 0, 0)] Manzana
# [datetime.datetime(2019, 3, 25, 0, 0), datetime.datetime(2019, 3, 29, 0, 0)] Naranja
# [datetime.datetime(2019, 3, 25, 0, 0), datetime.datetime(2019, 3, 29, 0, 0)] Palta
# [datetime.datetime(2019, 3, 25, 0, 0), datetime.datetime(2019, 3, 29, 0, 0)] Papa
# [datetime.datetime(2019, 3, 25, 0, 0), datetime.datetime(2019, 3, 29, 0, 0)] Pera
# [datetime.datetime(2019, 3, 25, 0, 0), datetime.datetime(2019, 3, 29, 0, 0)] Tomate
# [datetime.datetime(2019, 3, 25, 0, 0), datetime.datetime(2019, 3, 29, 0, 0)] Uva
# [datetime.datetime(2019, 3, 25, 0, 0), datetime.datetime(2019, 3, 29, 0, 0)] Zanahoria
# [datetime.datetime(2019, 4, 1, 0, 0), datetime.datetime(2019, 4, 5, 0, 0)] Cebolla
# [datetime.datetime(2019, 4, 1, 0, 0), datetime.datetime(2019, 4, 5, 0, 0)] Lechuga
# [datetime.datetime(2019, 4, 1, 0, 0), datetime.datetime(2019, 4, 5, 0, 0)] Limón
# [datetime.datetime(2019, 4, 1, 0, 0), datetime.datetime(2019, 4, 5, 0, 0)] Manzana
# [datetime.datetime(2019, 4, 1, 0, 0), datetime.datetime(2019, 4, 5, 0, 0)] Naranja
# [datetime.datetime(2019, 4, 1, 0, 0), datetime.datetime(2019, 4, 5, 0, 0)] Palta
# [datetime.datetime(2019, 4, 1, 0, 0), datetime.datetime(2019, 4, 5, 0, 0)] Papa
# [datetime.datetime(2019, 4, 1, 0, 0), datetime.datetime(2019, 4, 5, 0, 0)] Pera
# [datetime.datetime(2019, 4, 1, 0, 0), datetime.datetime(2019, 4, 5, 0, 0)] Tomate
# [datetime.datetime(2019, 4, 1, 0, 0), datetime.datetime(2019, 4, 5, 0, 0)] Uva
# [datetime.datetime(2019, 4, 1, 0, 0), datetime.datetime(2019, 4, 5, 0, 0)] Zanahoria
# [datetime.datetime(2019, 4, 8, 0, 0), datetime.datetime(2019, 4, 12, 0, 0)] Cebolla
# [datetime.datetime(2019, 4, 8, 0, 0), datetime.datetime(2019, 4, 12, 0, 0)] Lechuga
# [datetime.datetime(2019, 4, 22, 0, 0), datetime.datetime(2019, 4, 26, 0, 0)] Tomate
# [datetime.datetime(2019, 4, 22, 0, 0), datetime.datetime(2019, 4, 26, 0, 0)] Uva
# [datetime.datetime(2019, 4, 22, 0, 0), datetime.datetime(2019, 4, 26, 0, 0)] Zanahoria
# [datetime.datetime(2019, 4, 29, 0, 0), datetime.datetime(2019, 5, 3, 0, 0)] Cebolla
# [datetime.datetime(2019, 4, 29, 0, 0), datetime.datetime(2019, 5, 3, 0, 0)] Lechuga
# [datetime.datetime(2019, 4, 29, 0, 0), datetime.datetime(2019, 5, 3, 0, 0)] Limón
# [datetime.datetime(2019, 4, 29, 0, 0), datetime.datetime(2019, 5, 3, 0, 0)] Manzana
# [datetime.datetime(2019, 4, 29, 0, 0), datetime.datetime(2019, 5, 3, 0, 0)] Naranja
# [datetime.datetime(2019, 4, 29, 0, 0), datetime.datetime(2019, 5, 3, 0, 0)] Palta
# [datetime.datetime(2019, 4, 29, 0, 0), datetime.datetime(2019, 5, 3, 0, 0)] Papa
# [datetime.datetime(2019, 4, 29, 0, 0), datetime.datetime(2019, 5, 3, 0, 0)] Pera
# [datetime.datetime(2019, 4, 29, 0, 0), datetime.datetime(2019, 5, 3, 0, 0)] Tomate
# [datetime.datetime(2019, 4, 29, 0, 0), datetime.datetime(2019, 5, 3, 0, 0)] Uva
# [datetime.datetime(2019, 4, 29, 0, 0), datetime.datetime(2019, 5, 3, 0, 0)] Zanahoria
# [datetime.datetime(2019, 5, 6, 0, 0), datetime.datetime(2019, 5, 10, 0, 0)] Cebolla
# [datetime.datetime(2019, 5, 6, 0, 0), datetime.datetime(2019, 5, 10, 0, 0)] Lechuga
# [datetime.datetime(2019, 5, 6, 0, 0), datetime.datetime(2019, 5, 10, 0, 0)] Limón
# [datetime.datetime(2019, 5, 6, 0, 0), datetime.datetime(2019, 5, 10, 0, 0)] Manzana
# [datetime.datetime(2019, 5, 6, 0, 0), datetime.datetime(2019, 5, 10, 0, 0)] Naranja
# [datetime.datetime(2019, 5, 6, 0, 0), datetime.datetime(2019, 5, 10, 0, 0)] Palta
# [datetime.datetime(2019, 5, 6, 0, 0), datetime.datetime(2019, 5, 10, 0, 0)] Papa
# [datetime.datetime(2019, 5, 6, 0, 0), datetime.datetime(2019, 5, 10, 0, 0)] Pera
# [datetime.datetime(2019, 5, 6, 0, 0), datetime.datetime(2019, 5, 10, 0, 0)] Tomate
# [datetime.datetime(2019, 5, 6, 0, 0), datetime.datetime(2019, 5, 10, 0, 0)] Uva
# [datetime.datetime(2019, 5, 6, 0, 0), datetime.datetime(2019, 5, 10, 0, 0)] Zanahoria
# [datetime.datetime(2019, 5, 13, 0, 0), datetime.datetime(2019, 5, 17, 0, 0)] Cebolla
# [datetime.datetime(2019, 5, 13, 0, 0), datetime.datetime(2019, 5, 17, 0, 0)] Lechuga
# [datetime.datetime(2019, 5, 13, 0, 0), datetime.datetime(2019, 5, 17, 0, 0)] Limón
# [datetime.datetime(2019, 5, 13, 0, 0), datetime.datetime(2019, 5, 17, 0, 0)] Manzana
# [datetime.datetime(2019, 5, 13, 0, 0), datetime.datetime(2019, 5, 17, 0, 0)] Naranja
# [datetime.datetime(2019, 5, 13, 0, 0), datetime.datetime(2019, 5, 17, 0, 0)] Palta
# [datetime.datetime(2019, 5, 13, 0, 0), datetime.datetime(2019, 5, 17, 0, 0)] Papa
# [datetime.datetime(2019, 5, 13, 0, 0), datetime.datetime(2019, 5, 17, 0, 0)] Pera
# [datetime.datetime(2019, 5, 13, 0, 0), datetime.datetime(2019, 5, 17, 0, 0)] Tomate
# [datetime.datetime(2019, 5, 13, 0, 0), datetime.datetime(2019, 5, 17, 0, 0)] Uva
# [datetime.datetime(2019, 5, 13, 0, 0), datetime.datetime(2019, 5, 17, 0, 0)] Zanahoria
# [datetime.datetime(2019, 5, 20, 0, 0), datetime.datetime(2019, 5, 24, 0, 0)] Cebolla
# [datetime.datetime(2019, 5, 20, 0, 0), datetime.datetime(2019, 5, 24, 0, 0)] Lechuga
# [datetime.datetime(2019, 5, 20, 0, 0), datetime.datetime(2019, 5, 24, 0, 0)] Limón
# [datetime.datetime(2019, 5, 20, 0, 0), datetime.datetime(2019, 5, 24, 0, 0)] Manzana
# [datetime.datetime(2019, 5, 20, 0, 0), datetime.datetime(2019, 5, 24, 0, 0)] Naranja
# [datetime.datetime(2019, 5, 20, 0, 0), datetime.datetime(2019, 5, 24, 0, 0)] Palta
# [datetime.datetime(2019, 5, 20, 0, 0), datetime.datetime(2019, 5, 24, 0, 0)] Papa
# [datetime.datetime(2019, 5, 20, 0, 0), datetime.datetime(2019, 5, 24, 0, 0)] Tomate
# [datetime.datetime(2019, 5, 20, 0, 0), datetime.datetime(2019, 5, 24, 0, 0)] Pera
# [datetime.datetime(2019, 5, 20, 0, 0), datetime.datetime(2019, 5, 24, 0, 0)] Uva
# [datetime.datetime(2019, 5, 20, 0, 0), datetime.datetime(2019, 5, 24, 0, 0)] Zanahoria
# [datetime.datetime(2019, 5, 27, 0, 0), datetime.datetime(2019, 5, 31, 0, 0)] Cebolla
# [datetime.datetime(2019, 5, 27, 0, 0), datetime.datetime(2019, 5, 31, 0, 0)] Lechuga
# [datetime.datetime(2019, 5, 27, 0, 0), datetime.datetime(2019, 5, 31, 0, 0)] Limón
# [datetime.datetime(2019, 5, 27, 0, 0), datetime.datetime(2019, 5, 31, 0, 0)] Manzana
# [datetime.datetime(2019, 5, 27, 0, 0), datetime.datetime(2019, 5, 31, 0, 0)] Naranja
# [datetime.datetime(2019, 5, 27, 0, 0), datetime.datetime(2019, 5, 31, 0, 0)] Palta
# [datetime.datetime(2019, 5, 27, 0, 0), datetime.datetime(2019, 5, 31, 0, 0)] Papa
# [datetime.datetime(2019, 5, 27, 0, 0), datetime.datetime(2019, 5, 31, 0, 0)] Pera
# [datetime.datetime(2019, 5, 27, 0, 0), datetime.datetime(2019, 5, 31, 0, 0)] Tomate
# [datetime.datetime(2019, 9, 23, 0, 0), datetime.datetime(2019, 9, 27, 0, 0)] Limón
# [datetime.datetime(2019, 9, 23, 0, 0), datetime.datetime(2019, 9, 27, 0, 0)] Manzana
# [datetime.datetime(2019, 9, 23, 0, 0), datetime.datetime(2019, 9, 27, 0, 0)] Naranja
# [datetime.datetime(2019, 9, 23, 0, 0), datetime.datetime(2019, 9, 27, 0, 0)] Palta
# [datetime.datetime(2019, 9, 23, 0, 0), datetime.datetime(2019, 9, 27, 0, 0)] Papa
# [datetime.datetime(2019, 9, 23, 0, 0), datetime.datetime(2019, 9, 27, 0, 0)] Pera
# [datetime.datetime(2019, 9, 23, 0, 0), datetime.datetime(2019, 9, 27, 0, 0)] Tomate
# [datetime.datetime(2019, 9, 23, 0, 0), datetime.datetime(2019, 9, 27, 0, 0)] Zanahoria
# [datetime.datetime(2019, 9, 30, 0, 0), datetime.datetime(2019, 10, 4, 0, 0)] Cebolla
# [datetime.datetime(2019, 9, 30, 0, 0), datetime.datetime(2019, 10, 4, 0, 0)] Lechuga
# [datetime.datetime(2019, 9, 30, 0, 0), datetime.datetime(2019, 10, 4, 0, 0)] Limón
# [datetime.datetime(2019, 9, 30, 0, 0), datetime.datetime(2019, 10, 4, 0, 0)] Manzana
# [datetime.datetime(2019, 9, 30, 0, 0), datetime.datetime(2019, 10, 4, 0, 0)] Naranja
# [datetime.datetime(2019, 9, 30, 0, 0), datetime.datetime(2019, 10, 4, 0, 0)] Palta
# [datetime.datetime(2019, 9, 30, 0, 0), datetime.datetime(2019, 10, 4, 0, 0)] Papa
# [datetime.datetime(2019, 9, 30, 0, 0), datetime.datetime(2019, 10, 4, 0, 0)] Pera
# [datetime.datetime(2019, 9, 30, 0, 0), datetime.datetime(2019, 10, 4, 0, 0)] Tomate
# [datetime.datetime(2019, 9, 30, 0, 0), datetime.datetime(2019, 10, 4, 0, 0)] Zanahoria
# [datetime.datetime(2019, 10, 7, 0, 0), datetime.datetime(2019, 10, 11, 0, 0)] Cebolla
# [datetime.datetime(2019, 10, 7, 0, 0), datetime.datetime(2019, 10, 11, 0, 0)] Lechuga
# [datetime.datetime(2019, 10, 7, 0, 0), datetime.datetime(2019, 10, 11, 0, 0)] Limón
# [datetime.datetime(2019, 10, 7, 0, 0), datetime.datetime(2019, 10, 11, 0, 0)] Manzana
# [datetime.datetime(2019, 10, 7, 0, 0), datetime.datetime(2019, 10, 11, 0, 0)] Naranja
# [datetime.datetime(2019, 10, 7, 0, 0), datetime.datetime(2019, 10, 11, 0, 0)] Palta
# [datetime.datetime(2019, 10, 7, 0, 0), datetime.datetime(2019, 10, 11, 0, 0)] Papa
# [datetime.datetime(2019, 10, 7, 0, 0), datetime.datetime(2019, 10, 11, 0, 0)] Pera
# [datetime.datetime(2019, 10, 7, 0, 0), datetime.datetime(2019, 10, 11, 0, 0)] Tomate
# ...
# [datetime.datetime(2019, 11, 11, 0, 0), datetime.datetime(2019, 11, 15, 0, 0)] Cebolla
# [datetime.datetime(2019, 12, 16, 0, 0), datetime.datetime(2019, 12, 20, 0, 0)] Limón
# [datetime.datetime(2019, 12, 16, 0, 0), datetime.datetime(2019, 12, 20, 0, 0)] Manzana
# [datetime.datetime(2019, 12, 16, 0, 0), datetime.datetime(2019, 12, 20, 0, 0)] Naranja
# [datetime.datetime(2019, 12, 16, 0, 0), datetime.datetime(2019, 12, 20, 0, 0)] Palta
# [datetime.datetime(2019, 12, 16, 0, 0), datetime.datetime(2019, 12, 20, 0, 0)] Papa
# [datetime.datetime(2019, 12, 16, 0, 0), datetime.datetime(2019, 12, 20, 0, 0)] Pera
# [datetime.datetime(2019, 12, 16, 0, 0), datetime.datetime(2019, 12, 20, 0, 0)] Tomate
# [datetime.datetime(2019, 12, 16, 0, 0), datetime.datetime(2019, 12, 20, 0, 0)] Uva
# [datetime.datetime(2019, 12, 16, 0, 0), datetime.datetime(2019, 12, 20, 0, 0)] Zanahoria
# [datetime.datetime(2019, 12, 23, 0, 0), datetime.datetime(2019, 12, 27, 0, 0)] Cebolla
# [datetime.datetime(2019, 12, 23, 0, 0), datetime.datetime(2019, 12, 27, 0, 0)] Lechuga
# [datetime.datetime(2019, 12, 23, 0, 0), datetime.datetime(2019, 12, 27, 0, 0)] Limón
# [datetime.datetime(2019, 12, 23, 0, 0), datetime.datetime(2019, 12, 27, 0, 0)] Manzana
# [datetime.datetime(2019, 12, 23, 0, 0), datetime.datetime(2019, 12, 27, 0, 0)] Naranja
# [datetime.datetime(2019, 12, 23, 0, 0), datetime.datetime(2019, 12, 27, 0, 0)] Palta
# [datetime.datetime(2019, 12, 23, 0, 0), datetime.datetime(2019, 12, 27, 0, 0)] Papa
# [datetime.datetime(2019, 12, 23, 0, 0), datetime.datetime(2019, 12, 27, 0, 0)] Pera
# [datetime.datetime(2019, 12, 23, 0, 0), datetime.datetime(2019, 12, 27, 0, 0)] Tomate
# [datetime.datetime(2019, 12, 23, 0, 0), datetime.datetime(2019, 12, 27, 0, 0)] Uva
# [datetime.datetime(2019, 12, 23, 0, 0), datetime.datetime(2019, 12, 27, 0, 0)] Zanahoria
# [datetime.datetime(2019, 12, 30, 0, 0), datetime.datetime(2020, 1, 3, 0, 0)] Cebolla
# [datetime.datetime(2019, 12, 30, 0, 0), datetime.datetime(2020, 1, 3, 0, 0)] Lechuga
# [datetime.datetime(2019, 12, 30, 0, 0), datetime.datetime(2020, 1, 3, 0, 0)] Limón
# [datetime.datetime(2019, 12, 30, 0, 0), datetime.datetime(2020, 1, 3, 0, 0)] Manzana
# [datetime.datetime(2019, 12, 30, 0, 0), datetime.datetime(2020, 1, 3, 0, 0)] Naranja
# [datetime.datetime(2019, 12, 30, 0, 0), datetime.datetime(2020, 1, 3, 0, 0)] Palta
# [datetime.datetime(2019, 12, 30, 0, 0), datetime.datetime(2020, 1, 3, 0, 0)] Papa
# [datetime.datetime(2019, 12, 30, 0, 0), datetime.datetime(2020, 1, 3, 0, 0)] Pera
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 7
#       5 sheet_names = list(df_sheets.keys())[2:] #Remove 'Portada...' and 'Presentacion'
#       6 for sheet in sheet_names:
# ----> 7     df = pd.read_excel(path_data + data['file'], sheet_name=sheet)
#       8     print(extractDates(str(df.iloc[1][0])), sheet)
#
# File ~/anaconda3/envs/test-env/lib/python3.8/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/test-env/lib/python3.8/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/test-env/lib/python3.8/site-packages/pandas/io/excel/_base.py:482, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     480 if not isinstance(io, ExcelFile):
#     481     should_close = True
# --> 482     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     483 elif engine and engine != io.engine:
#     484     raise ValueError(
#     485         "Engine should not be specified when passing "
#     486         "an ExcelFile - ExcelFile already has the engine set"
#     487     )
#
# File ~/anaconda3/envs/test-env/lib/python3.8/site-packages/pandas/io/excel/_base.py:1695, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1692 self.engine = engine
#    1693 self.storage_options = storage_options
# -> 1695 self._reader = self._engines[engine](self._io, storage_options=storage_options)
#
# File ~/anaconda3/envs/test-env/lib/python3.8/site-packages/pandas/io/excel/_openpyxl.py:557, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options)
#     547 """
#     548 Reader using openpyxl engine.
#     549
#    (...)
#     554 {storage_options}
#     555 """
#     556 import_optional_dependency("openpyxl")
# --> 557 super().__init__(filepath_or_buffer, storage_options=storage_options)
#
# File ~/anaconda3/envs/test-env/lib/python3.8/site-packages/pandas/io/excel/_base.py:545, in BaseExcelReader.__init__(self, filepath_or_buffer, storage_options)
#     543 self.handles.handle.seek(0)
#     544 try:
# --> 545     self.book = self.load_workbook(self.handles.handle)
#     546 except Exception:
#     547     self.close()
#
# File ~/anaconda3/envs/test-env/lib/python3.8/site-packages/pandas/io/excel/_openpyxl.py:568, in OpenpyxlReader.load_workbook(self, filepath_or_buffer)
#     565 def load_workbook(self, filepath_or_buffer: FilePath | ReadBuffer[bytes]):
#     566     from openpyxl import load_workbook
# --> 568     return load_workbook(
#     569         filepath_or_buffer, read_only=True, data_only=True, keep_links=False
#     570     )
#
# File ~/anaconda3/envs/test-env/lib/python3.8/site-packages/openpyxl/reader/excel.py:346, in load_workbook(filename, read_only, keep_vba, data_only, keep_links, rich_text)
#     316 """Open the given filename and return the workbook
#     317
#     318 :param filename: the path to open or a file-like object
#    (...)
#     342
#     343 """
#     344 reader = ExcelReader(filename, read_only, keep_vba,
#     345                      data_only, keep_links, rich_text)
# --> 346 reader.read()
#     347 return reader.wb
#
# File ~/anaconda3/envs/test-env/lib/python3.8/site-packages/openpyxl/reader/excel.py:289, in ExcelReader.read(self)
#     287 self.read_manifest()
#     288 action = "read strings"
# --> 289 self.read_strings()
#     290 action = "read workbook"
#     291 self.read_workbook()
#
# File ~/anaconda3/envs/test-env/lib/python3.8/site-packages/openpyxl/reader/excel.py:147, in ExcelReader.read_strings(self)
#     145 strings_path = ct.PartName[1:]
#     146 with self.archive.open(strings_path,) as src:
# --> 147     self.shared_strings = reader(src)
#
# File ~/anaconda3/envs/test-env/lib/python3.8/site-packages/openpyxl/reader/strings.py:16, in read_string_table(xml_source)
#      13 strings = []
#      14 STRING_TAG = '{%s}si' % SHEET_MAIN_NS
# ---> 16 for _, node in iterparse(xml_source):
#      17     if node.tag == STRING_TAG:
#      18         text = Text.from_tree(node).content
#
# File ~/anaconda3/envs/test-env/lib/python3.8/xml/etree/ElementTree.py:1232, in iterparse.<locals>.iterator()
#    1230     if not data:
#    1231         break
# -> 1232     pullparser.feed(data)
#    1233 root = pullparser._close_and_return_root()
#    1234 yield from pullparser.read_events()
#
# File ~/anaconda3/envs/test-env/lib/python3.8/xml/etree/ElementTree.py:1274, in XMLPullParser.feed(self, data)
#    1272 if data:
#    1273     try:
# -> 1274         self._parser.feed(data)
#    1275     except SyntaxError as exc:
#    1276         self._events_queue.append(exc)
#
# File ~/anaconda3/envs/test-env/lib/python3.8/xml/etree/ElementTree.py:1693, in XMLParser.feed(self, data)
#    1691 """Feed encoded data to parser."""
#    1692 try:
# -> 1693     self.parser.Parse(data, 0)
#    1694 except self._error as v:
#    1695     self._raiseerror(v)
#
# File /pythoncroot3/python-split_1673995251207/work/Modules/pyexpat.c:459, in EndElement()
#
# File ~/anaconda3/envs/test-env/lib/python3.8/xml/etree/ElementTree.py:1564, in XMLParser._setevents.<locals>.handler(tag, event, append, end)
#    1562 def handler(tag, event=event_name, append=append,
#    1563             end=self._end):
# -> 1564     append((event, end(tag)))
#
# File ~/anaconda3/envs/test-env/lib/python3.8/xml/etree/ElementTree.py:1634, in XMLParser._end(self, tag)
#    1633 def _end(self, tag):
# -> 1634     return self.target.end(self._fixname(tag))
#
# File ~/anaconda3/envs/test-env/lib/python3.8/xml/etree/ElementTree.py:1607, in XMLParser._fixname(self, key)
#    1604 def _fixname(self, key):
#    1605     # expand qname, and convert name string to ascii, if possible
#    1606     try:
# -> 1607         name = self._names[key]
#    1608     except KeyError:
#    1609         name = key
#
# KeyboardInterrupt:

# %% [markdown]
# ### Cebollas test

# %%
test_df = pd.DataFrame()
df = pd.read_excel('./data/Boletin_Semanal_Precios_Mayoristas_20230714.xlsx', sheet_name='Cebolla')
extractDates(str(df.iloc[1][0]))

# %%
test_df = pd.concat([df, test_df])

# %%
test_df

# %%
df.columns = np.array(df.iloc[4])

# %%
df.drop(df[df['Mercado'].isnull() == True].index, axis=0, inplace=True)

# %%
df.drop(df[df['Mercado'] == 'Mercado'].index, axis=0, inplace=True)

# %%
df.reset_index(drop=True)

# %% [markdown]
# ### Manzanas

# %%
df2 = pd.read_excel('./data/Boletin_Semanal_Precios_Mayoristas_20230714.xlsx', sheet_name='Manzana', skiprows=0)
df2.shape
# Out:
# (59, 8)

# %%
df2.drop(df2[df2[df2.columns[1]].isnull() == True].index, axis=0, inplace=True)

# %%
df2.columns = np.array(df2.iloc[0])

# %%
df2.rename(columns={'Unidad de\ncomercialización ': 'Unidad'}, inplace=True)

# %%
df2.drop(df2[df2['Mercado'] == 'Mercado'].index, axis=0, inplace=True)

# %%
df2 = df2.reset_index(drop=True)
df2.head()

# %%
df2.rename(columns={'Unidad de\ncomercialización ': 'Unidad'}, inplace=True)
df2[df2['Unidad'].str.contains('\$') == False].head()

# %% [markdown]
# ## Transform data

# %%
price_df = df2[df2['Unidad'].str.contains('\$') == True]
volume_df = df2[df2['Unidad'].str.contains('\$') == False]
price_df = pd.melt(price_df, id_vars=['Variedad', 'Mercado', 'Unidad'], var_name='Dia', value_name='Precio')
volume_df = pd.melt(volume_df, id_vars=['Variedad', 'Mercado', 'Unidad'], var_name='Dia', value_name='Volumen')

# %%
start_date = pd.to_datetime('2023-03-14')

# Create a dictionary to map weekday names to their respective date offsets
weekday_to_offset = {
    'Lunes': 0,
    'Martes': 1,
    'Miércoles': 2,
    'Jueves': 3,
    'Viernes': 4
}

# Function to calculate the date for each weekday based on the start date
def calculate_date(row):
    offset = weekday_to_offset[row['Dia']]
    return start_date + pd.DateOffset(days=offset)

# Apply the function to create the 'Date' column
price_df['Fecha'] = price_df.apply(calculate_date, axis=1)
volume_df['Fecha'] = volume_df.apply(calculate_date, axis=1)

# %%
price_df['Unidad'] = volume_df['Unidad']

# %%
price_df.head()

# %%
merged_df = pd.merge(price_df, volume_df, on=['Variedad', 'Mercado', 'Dia', 'Fecha', 'Unidad'])
merged_df.head()

# %%
merged_df['Producto'] = 'Manzana'
merged_df.head()

# %%
product = 'Pera'
df = pd.read_excel('./data/Boletin_Semanal_Precios_Mayoristas_20230127.xlsx', sheet_name=product, skiprows=0)
start_date, end_date = extractDates(str(df.iloc[1][0]))
df.drop(df[df[df.columns[1]].isnull() == True].index, axis=0, inplace=True)
df.columns = np.array(df.iloc[0])
df.rename(columns={'Unidad de\ncomercialización ': 'Unidad'}, inplace=True)
df = df.reset_index(drop=True)
split = int(df[df['Mercado'] == 'Mercado'].index[int(len(df[df['Mercado'] == 'Mercado'].index)/2)])
df1 = df.iloc[:split].copy()
df2 = df.iloc[split:].copy()

# %%
df
# Out:
#               Variedad                                    Mercado   Lunes  \
# 0             Variedad                                    Mercado   Lunes
# 1   Bartlett de verano                      Vega Modelo de Temuco   16000
# 2    Favorita de Clapp                      Vega Modelo de Temuco   20000
# 3    Packham's Triumph                      Vega Modelo de Temuco   24000
# 4             Variedad                                    Mercado   Lunes
# 5   Bartlett de verano           Terminal La Palmera de La Serena  355000
# 6   Bartlett de verano                      Vega Modelo de Temuco  340000
# 7    Packham's Triumph                      Vega Modelo de Temuco  500000
# 8             Variedad                                    Mercado   Lunes
# 9   Bartlett de verano                      Vega Modelo de Temuco     200
# 10   Favorita de Clapp                      Vega Modelo de Temuco     300
# 11   Packham's Triumph                      Vega Modelo de Temuco     200
# 12            Variedad                                    Mercado   Lunes
# 13  Bartlett de verano  Mercado Mayorista Lo Valledor de Santiago      24
# 14  Bartlett de verano           Terminal La Palmera de La Serena      18
# 15  Bartlett de verano                      Vega Modelo de Temuco       4
# 16   Packham's Triumph                      Vega Modelo de Temuco       2
#
#     Martes  Miércoles  Jueves  Viernes                        Unidad
# 0   Martes  Miércoles  Jueves  Viernes  Unidad de\ncomercialización
# 1    16000      16000   16769    16000     $/bandeja 18 kilos granel
# 2        0          0   20000        0     $/bandeja 18 kilos granel
# 3        0      19111   20000    20000     $/bandeja 18 kilos granel
# 4   Martes  Miércoles  Jueves  Viernes  Unidad de\ncomercialización
# 5   355000          0  345000   335000             $/bin (450 kilos)
# 6        0          0       0        0             $/bin (450 kilos)
# 7   500000          0  500000        0             $/bin (450 kilos)
# 8   Martes  Miércoles  Jueves  Viernes  Unidad de\ncomercialización
# 9      100        300     650      250       Bandeja 18 kilos granel
# 10       0          0     250        0       Bandeja 18 kilos granel
# 11       0        450     350      180       Bandeja 18 kilos granel
# 12  Martes  Miércoles  Jueves  Viernes  Unidad de\ncomercialización
# 13       0         10      30       30               Bin (450 kilos)
# 14      18          0      20       20               Bin (450 kilos)
# 15       0          0       0        0               Bin (450 kilos)
# 16       1          0       2        0               Bin (450 kilos)

# %%
df1.drop(df1[df1['Mercado'] == 'Mercado'].index, axis=0, inplace=True)

# %%
df2.drop(df2[df2['Mercado'] == 'Mercado'].index, axis=0, inplace=True)

# %%
df1.reset_index(drop=True)
# Out:
#              Variedad                           Mercado   Lunes  Martes  \
# 0  Bartlett de verano             Vega Modelo de Temuco   16000   16000
# 1   Favorita de Clapp             Vega Modelo de Temuco   20000       0
# 2   Packham's Triumph             Vega Modelo de Temuco   24000       0
# 3  Bartlett de verano  Terminal La Palmera de La Serena  355000  355000
# 4  Bartlett de verano             Vega Modelo de Temuco  340000       0
# 5   Packham's Triumph             Vega Modelo de Temuco  500000  500000
#
#   Miércoles  Jueves Viernes                     Unidad
# 0     16000   16769   16000  $/bandeja 18 kilos granel
# 1         0   20000       0  $/bandeja 18 kilos granel
# 2     19111   20000   20000  $/bandeja 18 kilos granel
# 3         0  345000  335000          $/bin (450 kilos)
# 4         0       0       0          $/bin (450 kilos)
# 5         0  500000       0          $/bin (450 kilos)

# %%
df2.reset_index(drop=True)
# Out:
#              Variedad                                    Mercado Lunes Martes  \
# 0  Bartlett de verano                      Vega Modelo de Temuco   200    100
# 1   Favorita de Clapp                      Vega Modelo de Temuco   300      0
# 2   Packham's Triumph                      Vega Modelo de Temuco   200      0
# 3  Bartlett de verano  Mercado Mayorista Lo Valledor de Santiago    24      0
# 4  Bartlett de verano           Terminal La Palmera de La Serena    18     18
# 5  Bartlett de verano                      Vega Modelo de Temuco     4      0
# 6   Packham's Triumph                      Vega Modelo de Temuco     2      1
#
#   Miércoles Jueves Viernes                   Unidad
# 0       300    650     250  Bandeja 18 kilos granel
# 1         0    250       0  Bandeja 18 kilos granel
# 2       450    350     180  Bandeja 18 kilos granel
# 3        10     30      30          Bin (450 kilos)
# 4         0     20      20          Bin (450 kilos)
# 5         0      0       0          Bin (450 kilos)
# 6         0      2       0          Bin (450 kilos)

# %%
product = 'Pera'
df = pd.read_excel('./data/Boletin_Semanal_Precios_Mayoristas_20220722.xlsx', sheet_name=product, skiprows=0)
df.drop(df[df[df.columns[1]].isnull() == True].index, axis=0, inplace=True)
df.columns = np.array(df.iloc[0])
df.rename(columns={'Unidad de\ncomercialización ': 'Unidad'}, inplace=True)
df = df.reset_index(drop=True)
split_index = int(df[df['Mercado'] == 'Mercado'].index[int(len(df[df['Mercado'] == 'Mercado'].index)/2)])
price_df = df.iloc[:split_index].copy()
volume_df = df.iloc[split_index:].copy()
price_df.drop(price_df[price_df['Mercado'] == 'Mercado'].index, axis=0, inplace=True)
volume_df.drop(volume_df[volume_df['Mercado'] == 'Mercado'].index, axis=0, inplace=True)
if (end_date - start_date) < timedelta(days=4):
    if 'Viernes' not in price_df.columns:
        price_df.insert(loc=len(price_df.columns), column='Viernes', value=0.0)
        volume_df.insert(loc=len(volume_df.columns), column='Viernes', value=0.0)
    end_date = end_date + timedelta(days=1)
price_df = pd.melt(price_df, id_vars=['Variedad', 'Mercado', 'Unidad'], var_name='Dia', value_name='Precio')
volume_df = pd.melt(volume_df, id_vars=['Variedad', 'Mercado', 'Unidad'], var_name='Dia', value_name='Volumen')
# Function to calculate the date for each weekday based on the start date
def calculate_date(row):
    weekday_to_offset = {
        'Lunes': 0,
        'Martes': 1,
        'Miércoles': 2,
        'Jueves': 3,
        'Viernes': 4
    }
    offset = weekday_to_offset[row['Dia']]
    return start_date + pd.DateOffset(days=offset)

# Apply the function to create the 'Date' column
price_df['Fecha'] = price_df.apply(calculate_date, axis=1)
volume_df['Fecha'] = volume_df.apply(calculate_date, axis=1)

price_df['Unidad'] = volume_df['Unidad']

merged_df = pd.merge(price_df, volume_df, on=['Variedad', 'Mercado', 'Unidad', 'Dia', 'Fecha'], how='outer')
merged_df.sort_values(by='Fecha')
# Out:
#              Variedad                                    Mercado  \
# 0   Packham's Triumph  Mercado Mayorista Lo Valledor de Santiago
# 7        Winter Nelis                 Vega Monumental Concepción
# 6   Packham's Triumph                 Vega Monumental Concepción
# 5         Abate Fetel                 Vega Monumental Concepción
# 40  Packham's Triumph       Terminal Hortofrutícola Agro Chillán
# ..                ...                                        ...
# 35       Winter Nelis  Mercado Mayorista Lo Valledor de Santiago
# 36       Winter Nelis           Terminal La Palmera de La Serena
# 37        Abate Fetel                 Vega Monumental Concepción
# 39       Winter Nelis                 Vega Monumental Concepción
# 63       Winter Nelis                 Vega Monumental Concepción
#
#                      Unidad      Dia  Precio      Fecha Volumen
# 0           Bin (450 kilos)    Lunes  140000 2023-01-23      35
# 7   Caja 16 kilos empedrada    Lunes       0 2023-01-23       0
# 6   Caja 16 kilos empedrada    Lunes       0 2023-01-23       0
# 5   Caja 16 kilos empedrada    Lunes       0 2023-01-23       0
# 40  Caja 16 kilos empedrada    Lunes     NaN 2023-01-23       0
# ..                      ...      ...     ...        ...     ...
# 35  Caja 16 kilos empedrada  Viernes       0 2023-01-27     NaN
# 36          Bin (450 kilos)  Viernes       0 2023-01-27       0
# 37          Bin (450 kilos)  Viernes    8000 2023-01-27     NaN
# 39          Bin (450 kilos)  Viernes    8000 2023-01-27     NaN
# 63  Caja 16 kilos empedrada  Viernes     NaN 2023-01-27      50
#
# [64 rows x 7 columns]

# %%
merged_df['Precio'].sum(), merged_df['Volumen'].sum()
# Out:
# (3000833, 1143)

# %%
merged_df['Mercado'].unique()
# Out:
# array(['Vega Modelo de Temuco', 'Terminal La Palmera de La Serena',
#        'Mercado Mayorista Lo Valledor de Santiago'], dtype=object)
